# %% [markdown]
# #### Example

# %%
L = [1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 L = [1,2,3]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'
s.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 s = 'hello'
# ----> 2 s.append()
#
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# what is object which is giving error

# %% [markdown]
# #### Object and Classes

# %%
class myAtm:

    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()

    def menu(self):
        user_input = input("""
        Hii, How are you ? 
        1. Press 1 to create a pin
        2. press 2 to change pin 
        3. press 3 to check balance
        4. press 4 to withdraw
        """)

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.change_pin()
        elif user_input == '3':
            pass
        else:
            exit()   

    def create_pin(self):
        user_pin = input("Enter your pin")
        self.pin = user_pin
        
        user_balance = int(input("Enter user balance "))
        self.balance = user_balance
        print("pin created sucessfully!")

    # change pin function 
    def change_pin(self):
        print(self.pin)c

# %%
atm = myAtm()
# Out:
#         Hii, How are you ?
#         1. Press 1 to create a pin
#         2. press 2 to change pin
#         3. press 3 to check balance
#         4. press 4 to withdraw
#          2

# %% [markdown]
# # atm.pin

# %%
atm.balance
# Out:
# 1234
