# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance.csv')
df.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 774    41    male  34.200         2     no  northwest   7261.74100
# 219    24  female  23.210         0     no  southeast  25081.76784
# 1258   55    male  37.715         3     no  northwest  30063.58055
# 452    24    male  23.400         0     no  southwest   1969.61400
# 311    19  female  24.700         0     no  southwest   1737.37600

# %%
plt.scatter(df['age'],df['charges'])

# %%
# implementing code on age vs charge
class SimpleLinearRegression:

    def __init__(self):
        self.intercept = 0
        self.coef = 0
    def fit(self,X_train,y_train):
        num = 0
        den = 0
        for i in range(X_train.shape[0]):
            num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
            den = den + ((X_train[i] - X_train.mean())*(X_train[i]- X_train.mean()))
        self.intercept = num/den
        self.coef =y_train.mean() - (self.intercept*X_train.mean())

    def test(self,X_train):
        return (self.intercept*X_train) + self.coef

# %%
lr = SimpleLinearRegression()

# %%
X = df.iloc[:,0].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2, test_size = 0.2)

# %%
lr.fit(X_train,y_train)

# %%
lr.intercept
# Out:
# 250.2277153673341

# %%
lr.coef
# Out:
# 3491.532606349525

# %%
lr.intercept*41 + lr.coef
# Out:
# 13750.868936410223

# %%
plt.scatter(df['age'],df['charges'])
plt.plot(X,lr.test(X))
