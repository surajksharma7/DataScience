# %% [markdown]
# ### Python Output

# %%
print("hello world!")
# Out:
# hello world!

# %%
 print("salmaan Khan")
# Out:
# salmaan Khan

# %%
print(Salmaan Khan)

# %%
print(7)
# Out:
# 7

# %%
print(True)
# Out:
# True

# %% [markdown]
# ### Seprator

# %%
print("hello","world")
# Out:
# hello world

# %%
print("hello ",end="---")
print(" world")
# Out:
# hello --- world

# %% [markdown]
# ### Datatypes in Python

# %%
print(5)
print(1e308)
# Out:
# 5
# 1e+308

# %%
print(5.5)
print(1e308)
# Out:
# 5.5
# 1e+308

# %%
print(True)
# Out:
# True

# %%
print("")
