# %% [markdown]
# Design philosphy -- Easiest langauge, Well idented
#
# Batteries Included -- provieded all functionalities
#
# General purpose programming langauge - OOPs, procedural programming, functional programming
#
# Libraries/Community -

# %% [markdown]
# ### Why Python for data science

# %% [markdown]
# Easy to learn
#
# proximity with maths
