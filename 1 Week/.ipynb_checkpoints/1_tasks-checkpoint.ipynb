# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data","Science","Mentorship","program","by","campusX",sep="-")
# Out:
# Data-Science-Mentorship-program-by-campusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
celcius = float(input("Enter temprature in celcius "))

fahrenheit = celcius * (9/5) + 32

print("the temprature in fahrenheit is {} and in celcius it is {} ".format(fahrenheit,celcius))
# Out:
# Enter temprature in celcius  100
# the temprature in fahrenheit is 212.0 and in celcius it is 100.0

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
fnum = int(input("Enter first value "))
snum = int(input("Enter second value "))

fnum = fnum + snum 
snum = fnum - snum
fnum = fnum - snum

print(snum)
print(fnum)
# Out:
# Enter first value  10
# Enter second value  20
# 10
# 20

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
x1,y1 = map(int,input("Enter first distance ").split())
x2,y2= map(int,input("Enter first distance ").split())

X = (x1 - x2)**2
Y = (y1 - y2)**2

distance = (X+Y)**0.5

print(distance )
# Out:
# Enter first distance  10 10
# Enter first distance  10 10
# 0.0

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here

principle = float(input("Enter principle "))
rate = float(input("enter rate "))
time = float(input("enter time "))

si = (principle * rate * time)/100
print (si+principle)
# Out:
# Enter principle  100
# enter rate  10
# enter time  1
# 110.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
head = int(input("Enter total head "))
leg = int(input("Enter total leg "))

chicken  = 2*head - (leg/2)
dog = head - chicken

print("total number of dog is {}".format(int(dog)))
print("total number of chicken is {}".format(int(chicken)))
# Out:
# Enter total head  4
# Enter total leg  12
# total number of dog is 2
# total number of chicken is 2

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
nth = int(input("Enter nth value to find sum "))
sum =  (nth*(nth+1)*(2*nth+1)) / 6
print("the sum of {} square is {}".format(nth,sum))
# Out:
# Enter nth value to find sum  10
# the sum of 10 square is 385.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
first_val = int(input("Enter first value "))
common_diff = int(input("Enter common difference "))
nth = int(input("Enter nth term "))

value = first_val + (nth -1 )* common_diff
print(f"the {nth} term of ap will be {value} ")
# Out:
# Enter first value  10
# Enter common difference  10
# Enter nth term  10
# the 10 term of ap will be 100

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
num1,den1 = map(int,input("Enter first fraction value  ").split())
num2,den2 = map(int,input("Enter second fraction value ").split())

num = (num1*den2)+(num2*den1)
den = den1*den2

print(f"the sum of {num1}/{den1} and {num2}/{den2} is {num}/{den}")
# Out:
# Enter first fraction value   10 10
# Enter second fraction value  10 10
# the sum of 10/10 and 10/10 is 200/100

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
height,lenght,bredth = map(int,input("Enter height length and bredth of milk tank ").split())
height_g ,radius = map(int,input("Enter height of glass ").split())

area = height*lenght*bredth 

area_g = height_g*radius*3.14

total_g = area/area_g

print(f"the total glass which can be filled with tank is {total_g} ")
# Out:
# Enter height length and bredth of milk tank  20 20 20
# Enter height of glass  3 1
# the total glass which can be filled with tank is 849.2569002123142
