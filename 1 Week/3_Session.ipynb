# %% [markdown]
# ### Strings

# %% [markdown]
# In Python Specifically, Strings are a sequence of Unicode characters

# %% [markdown]
# #### Creating strings

# %%
fstr = 'suraj'
sstr = "Suraj"
tstr = '''Suraj'''
dfstr  = """Suraj"""
sg = str('hello')

# %% [markdown]
# ### Indexing

# %%
# positive Indexing
s = 'hello world'
s[0]
# Out:
# 'h'

# %%
# negative Indexing
s[-1]
# Out:
# 'd'

# %% [markdown]
# ### Slicing

# %%
s[0:6:2]
# Out:
# 'hlo'

# %%
s[::-1]
# Out:
# 'dlrow olleh'

# %%
s[6::-1]
# Out:
# 'w olleh'

# %%
s[-1:-6:-1]
# Out:
# 'dlrow'

# %% [markdown]
# ### Deleting Editing in String

# %%
s[0] = 'h'
# Python Strings are immutale
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s[0] = 'h'
#
# TypeError: 'str' object does not support item assignment

# %%
# deleting string 
del s

# %%
# del s[-1:-5:2] print s 
# output --> will throw error

# %% [markdown]
# ### Operations on strings

# %% [markdown]
# #### arithmetic operatons

# %%
# Addition 
print('delhi' + ' Mumbai')
# Out:
# delhi Mumbai

# %%
# multiplication 
print("*"*50)
# Out:
# **************************************************

# %% [markdown]
# ### Relational Operations

# %%
# euqals to 
'delhi'== 'Delhi'
# Out:
# False

# %%
# greater than equal to 
'mumbai' >= 'pune'
# Out:
# False

# %%
# compares lexiographically
'pune' > 'pune'
# Out:
# False

# %%
# pune, Pune
'Pune' > 'pune'
# Out:
# False

# %% [markdown]
# ### Logical Operations

# %%
'hello' and 'world' # 1 and 1 = 1
# Out:
# 'world'

# %%
'hello' or 'world' # 1 or 1 = 0
# Out:
# 'hello'

# %%
not ''# not 0 = 1 / not 1 = 0
# Out:
# True

# %% [markdown]
# ### String Functions

# %% [markdown]
# #### Common Functions

# %% [markdown]
# - len
# - max
# - min
# - sorted

# %%
len('hello world')
# Out:
# 11

# %%
max('hello world')
# Out:
# 'w'

# %%
min('hello world')
# Out:
# ' '

# %%
sorted('hello',reverse=True)
# Out:
# ['o', 'l', 'l', 'h', 'e']

# %%
sorted('hello')
# Out:
# ['e', 'h', 'l', 'l', 'o']

# %% [markdown]
# #### Capitalize/Title/Upper/Lower/Swapcase

# %%
s = 'hello world'
s.capitalize()
# Out:
# 'Hello world'

# %%
s.swapcase()
# Out:
# 'HELLO WORLD'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %% [markdown]
# #### Count/Find/Index

# %%
'my name is nitish'.count('i')
# Out:
# 3

# %%
'my name is nitish'.find('i')
# Out:
# 8

# %%
'my name is nitish'.index('i')
# Out:
# 8

# %% [markdown]
# #### Endswith/Startwith

# %%
'suraj'.endswith('i')
# Out:
# False

# %%
'suraj'.endswith('k')
# Out:
# False

# %% [markdown]
# #### format

# %%
name = 'suraj'
age = 17

'hii my name is {1} and im of {1}'.format(name,age)
# Out:
# 'hii my name is 17 and im of 17'

# %% [markdown]
# #### isalnum/ isalpha / isdigit / isidentifier

# %%
'nitish'.isalnum()
# Out:
# True

# %%
'nitish'.isalpha()
# Out:
# True

# %%
'suraj'.isdigit()
# Out:
# False

# %%
'suraj'.isidentifier()
# Out:
# True

# %% [markdown]
# #### Split

# %%
'hii my name is nitish'.split()
# Out:
# ['hii', 'my', 'name', 'is', 'nitish']

# %% [markdown]
# #### join

# %%
" ".join(['hii', 'my', 'name', 'is', 'nitish'])
# Out:
# 'hii my name is nitish'

# %% [markdown]
# #### Replace

# %%
'hii my name is suraj'.replace('suraj','nitish')
# Out:
# 'hii my name is nitish'

# %% [markdown]
# #### Strip

# %%
'suraj                        '.strip()
# Out:
# 'suraj'
