# %% [markdown]
# #### Python Output

# %%
print("Namaste Duniya")
# Out:
# Namaste Duniya

# %%
print("salmaan Khan")
# Out:
# salmaan Khan

# %%
print(salmaan khan) #--> this will raise error

# %%
print("hello", 1, 4.5, True)
# Out:
# hello 1 4.5 True

# %%
# using sep method 
print("hello", 1, 4.5, True,sep='/')
# Out:
# hello/1/4.5/True

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello" , end=' ')
print("world")
# Out:
# hello world

# %%
print("hello" , end='-')
print("world")
# Out:
# hello-world

# %% [markdown]
# #### Data Types

# %%
#integer
print(87)
# Out:
# 87

# %%
#Decimal / float
print(88.8)
# Out:
# 88.8

# %%
# string 
print("suraj kumar sharma")
# Out:
# suraj kumar sharma

# %%
# Boolean
print(True)
# Out:
# True

# %%
# Comples
print(5+7j)
# Out:
# (5+7j)

# %%
# list 
print([1,2,3,4,"suraj", 6+8j])
# Out:
# [1, 2, 3, 4, 'suraj', (6+8j)]

# %%
# tuple 
print((1,2,3,4,"suraj", 6+8j))
# Out:
# (1, 2, 3, 4, 'suraj', (6+8j))

# %%
# sets 
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
print({
    "name":"suraj",
    "class" : "MCA",
    "major" : "Artifial Intelligence"
})
# Out:
# {'name': 'suraj', 'class': 'MCA', 'major': 'Artifial Intelligence'}

# %%
type(5)
# Out:
# int

# %% [markdown]
# #### Keywords

# %% [markdown]
# a reserved word with a specific meaning and purpose in Python

# %% [markdown]
#   ![image.png](attachment:2565a0cd-0ac0-47e3-89f6-e561d53a8f8b.png)

# %% [markdown]
# #### Identifiers

# %% [markdown]
# a name given to an object, such as a variable, function, class, or module

# %% [markdown]
# #### User Input

# %%
input("Enter your email")
# Out:
# Enter your email suraj@gmail.com
# 'suraj@gmail.com'

# %%
# take 2 input from user 
num1 = input("Enter first Number ")
num2 = input("Enter second number ")

# add them in a variable
sum = int(num1) + int(num2)

# print variable
print("the sum of" , num1 , "and", num2 , "is", sum, sep=" ")
# Out:
# Enter first Number  10
# Enter second number  10
# the sum of 10  and 10 is 20
