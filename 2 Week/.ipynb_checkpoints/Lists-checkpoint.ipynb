# %%
a = 2
print(id(a))
print(id(2))
# Out:
# 140726513973720
# 140726513973720

# %% [markdown]
# ### Creating a list

# %%
# empty list 
a = []
print(a)
# Out:
# []

# %%
# 1d list 
a = [1,2,3]
print(a)
# Out:
# [1, 2, 3]

# %%
# 2d list 
a = [[1,2],[3,4]]
print(a)
# Out:
# [[1, 2], [3, 4]]

# %%
# 3d list 
a = [[[1,2],[3,4]],[[5,6],[7,8]]]
print(a)
# Out:
# [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]

# %%
# hetrogenous list 
a = ['suraj',15,6.6]
print(a)
# Out:
# ['suraj', 15, 6.6]

# %%
# type conversion 
print(list('hello'))
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# ### Accessing items from list

# %%
# indexing

# %%
# +ve indexing
a = [1,2,3]
print(a[1])
# Out:
# 2

# %%
# -ve indexing 
print(a[-1])
# Out:
# 3

# %%
# indexing from 2d array
a = [[1,2],[3,4]]
print(a[-1][-1])
# Out:
# 4

# %%
# indexing from 3d array 
a = [[[1,2],[3,4]],[[5,6],[7,8]]]
print(a[-1][-1][1])
# Out:
# 8

# %%
a[0][0][1]
# Out:
# 2

# %%
# slicing
l = [1,2,3,4,5,6]
print(l[::])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(l[-3:])
# Out:
# [4, 5, 6]

# %%
print(l[0::2])
# Out:
# [1, 3, 5]

# %% [markdown]
# ### Adding items to a list

# %%
l = [1,2,3,4,5,6]

# %%
# append 
l.append(5)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 5]

# %%
# extend 
l.extend([6,7,8])
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 5, 6, 7, 8]

# %%
# insert 
l.insert(0,[1,2])
print(l)
# Out:
# [[1, 2], 1, 2, 3, 4, 5, 6, 5, 6, 7, 8]

# %% [markdown]
# ### Editing items in list

# %%
l
# Out:
# [[1, 2], 1, 2, 3, 4, 5, 6, 5, 6, 7, 8]

# %%
l[0] = 0
print(l)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 5, 6, 7, 8]

# %%
l[0:4] = [0,1,2,3,4]

# %%
print(l)
# Out:
# [0, 1, 2, 3, 4, 4, 5, 6, 5, 6, 7, 8]

# %% [markdown]
# ### Deleting items from list

# %%
# del 
print(l)
del l[-1]
print(l)
# Out:
# [1, 2, 3, 5, 6]
# [1, 2, 3, 5]

# %%
# remove
l = [1,2,3,4,5,6]
l.remove(4)
print(l)
# Out:
# [1, 2, 3, 5, 6]

# %%
# pop
l.pop()
# Out:
# 5

# %%
# clear
l.clear()

# %%
print(l)
# Out:
# []

# %% [markdown]
# ### Operations

# %%
# Artihmetic 
# membership operators 
# loops

# %%
l1 = [1,2,3,4]
l2 = [1,2,3,4]
print(l1+l2)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
print(l1 * 2)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
# in / not in 
5 in l1
# Out:
# False

# %%
4 in l2
# Out:
# True

# %%
# loops 
for i in l1:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
l1
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### list functions

# %%
print(l1)
# Out:
# [1, 2, 3, 4]

# %%
len(l1)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
max(l)
# Out:
# 4

# %%
sorted(l,reverse=True)
# Out:
# [4, 3, 2, 1]

# %%
l.count(1)
# Out:
# 1

# %%
l.index(1)
# Out:
# 0

# %%
l.reverse()
print(l)
# Out:
# [4, 3, 2, 1]

# %%
l.sort()
print(l) # sort is permanent operation
# Out:
# [1, 2, 3, 4]

# %%
# copy
l1 = l.copy()

# %%
print(l)
print(l1)
print(id(l))
print(id(l1))
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]
# 1956739906176
# 1956748817408

# %% [markdown]
# ### List comprehension

# %% [markdown]
# ## List Comprehension
#
# List Comprehension provides a concise way of creating lists.
#
# newlist = [expression for item in iterable if condition == True]![image.png](data:image/png;base64,...)
#
# Advantages of List Comprehension
# - More time-efficient and space-efficient than loops.
# - Require fewer lines of code.
# - Transforms iterative statement into a formula.

# %%
# print all number divisible by 5 in the range of 1 to 50 
[i for i in range(1,51) if i%5 ==0]
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
# find langauges which nake start with letter p
langauge = ['java','python']
[i for i in langauge if i.startswith('p')]
# Out:
# ['python']

# %%
basket = ['apple','guava','cherry','banana']
my_fruits = ['apple','kiwi','grapes','banana']

# add new list from my_fruits and items if the fruit exists in basket and also starts with 'a'
[fruit for fruit in my_fruits if fruit in basket if fruit.startswith('a') ]
# Out:
# ['apple']

# %%
# print a (3,3) matrix using list comprehension  --> nested list comprehension 
[[i*j for i in range(1,4)] for j in range(1,4)]
# Out:
# [[1, 2, 3], [2, 4, 6], [3, 6, 9]]

# %% [markdown]
# ### 2 ways to traverse a list

# %%
# itemwise
# indexwise

# %%
l = [1,2,3,4]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(0,len(l)):
    print(l[i])
# Out:
# 0
# 1
# 1
# 2
# 2
# 3
# 3
# 4

# %%
for i in range(0,len(l)):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ### Zip function

# %% [markdown]
# ## Zip
#
# The zip() function returns a zip object, which is an iterator of tuples where the first item in each passed iterator is paired together, and then the second item in each passed iterator are paired together.
#
# If the passed iterators have different lengths, the iterator with the least items decides the length of the new iterator.

# %%
l1 = [1,2,3,4]
l2 = [5,6,7,8]
l3 = zip(l1,l2)

# %%
list(l3)
# Out:
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
[i+j for i,j in zip(l1,l2)]
# Out:
# [6, 8, 10, 12]

# %% [markdown]
# ### Disadvantage

# %%
# slow 
# risky usage 
# eats up more memory
